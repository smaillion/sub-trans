# %%
import torch

# %%
import whisper
from datetime import timedelta
# import torch

# device: str = "cuda" if torch.cuda.is_available() else "cpu"
# print(device)
sample_file_path: str = "E:\\Translation\\岬なこのそんなこんなこラジオ！第8回.mp4"

model = whisper.load_model("large-v3", device="cpu")
result = model.transcribe(audio=sample_file_path, 
                          verbose=False,
                          language='ja',
                          temperature=0.5,
                          condition_on_previous_text=True,
                          
                          initial_prompt='岬なこのそんなこんなこラジオ', 
                          no_speech_threshold=0.9)
segments = result['segments']

for segment in segments:
    startTime = str(0)+str(timedelta(seconds=int(segment['start'])))+',000'
    endTime = str(0)+str(timedelta(seconds=int(segment['end'])))+',000'
    text = segment['text']
    segmentId = segment['id']+1
    segment = f"{segmentId}\n{startTime} --> {endTime}\n{text[1:] if text[0] is ' ' else text}\n\n"

    srtFilename = os.path.join(sample_file_path, "srt")
    with open(srtFilename, 'a', encoding='utf-8') as srtFile:
        srtFile.write(segment)

# %%
import re
from openai import OpenAI

# OpenAI API配置
api_key = "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"  # 替换为你的API密钥
# headers = {
#     "Authorization": f"Bearer {api_key}",
#     "Content-Type": "application/json",
# }

# 用户词典
user_dictionary = {
    "なこちゃん": "nako酱",
    "どんどんパフパフ": "咚咚啪敷啪敷",
    "サイン": "签名",
    "ファーストシングル": "一单",
    "フォースライブ": "4th live",
    "ふーんイェーイ": "芜~耶~",
    "セカンド": "2nd",
    "セカンドライブ": "2nd live",
    "常夏さん社員": "常夏サンシャイン",
    "常夏": "常夏",
    "ファン": "粉丝",
    "リエラ": "Liella!",
    "フェス": "fes",
    "リリースイベント": "发售活动",
    "バイスシュバルツ": "黑白双翼",
    "ライオンさん": "狮子"
}

def translate_with_context(text, context):
    """
    使用GPT-4 API进行逐行翻译，同时提供上下文。
    """
#     # 构建请求数据
#     data = {
#         "model": "gpt-4",  # 确保使用最新的GPT-4模型
#         "messages": [
#           {
#             "role": "system",
#             "content": "You are a helpful assistant."
#           },
#           {
#             "role": "user",
#             "content": "Hello!"
#           }
#         ]
#     }

#     # 发送请求
#     response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=data)
#     result = response.json()
    print(text)
    client = OpenAI(
        # This is the default and can be omitted
        api_key=api_key,
    )
    MODEL = "gpt-4"
    response = client.chat.completions.create(
        model=MODEL,
        messages=[
#             {"role": "user", "content": "你是一名翻译官，在帮我逐行翻译一段有前后文联系的字幕片段。语种是从日文翻译成中文。必须严格遵守后面叙述的所有规则。"},
#             {"role": "user", "content": "规则：1.不要加入新的标点符号，但原文里就有的符号还请原样保留，不要根据语种作出任何修改 2.用空格代替逗号 3.尽可能使用比较口语的表述 4.直接返回翻译好的句子即可，不要输出任何其他类似“这一行的翻译是：”一类的说明文字。"},
#             {"role": "user", "content": "规则：5.原本就是中文或英文的词就保留原文 6.所有的英文字母和数字都保留原文 7.无法翻译的情况也输出原文。"},
#             {"role": "user", "content": f"包含前10行的上下文是这样的：{context}"},
            {"role": "user", "content": f"""
             你是一名翻译官，在帮我逐行翻译一段有前后文联系的字幕片段。语种是从日文翻译成中文。必须严格遵守后面叙述的所有规则。
             包含前10行的上下文是这样的：{context}
             需要翻译的文字是：{text}
             规则：
             1.不要加入新的标点符号，但原文里就有的符号还请原样保留，不要根据语种作出任何修改 
             2.用空格代替逗号 
             3.直接返回翻译好的翻译对象即可，不要输出任何其他类似“需要翻译的行是：”一类的说明文字，不要输出原文和其他冗余信息
             4.原本就是中文或英文的词就保留原文 
             5.所有的英文字母和数字都保留原文 
           
             """},
        ],
        temperature=0.8,
    )

    # 返回翻译结果
    result = response.choices[0].message.content
    print(result)
    return result

def main(input_file_path, output_file_path):
    with open(input_file_path, 'r', encoding='utf-8') as infile:
        lines = infile.readlines()

    total_lines = len(lines)  # 获取总行数

    with open(output_file_path, 'w', encoding='utf-8') as outfile:
        context_lines = []  # 存储最近的10行
    
        for index, line in enumerate(lines):
            # 显示进度
            print(f"Progress: {index+1}/{total_lines} lines", end='\r')
            
            # 确定行是时间轴还是对话
            if "-->" in line:
                outfile.write(line)  # 直接写入时间轴
                context_lines = []  # 重置上下文
            elif re.match(r"^\d+$", line.strip()) or line.strip() == "":
                continue
                
            else:
                # 检查用户词典
                for jp, cn in user_dictionary.items():
                    line = line.replace(jp, cn)

                # 构建上下文
                context = "\n".join(context_lines[-10:])  # 获取最近的10行作为上下文

                # 翻译
                translated_line = translate_with_context(line, context)
                outfile.write(line + " " + translated_line + "\n")

                # 更新上下文
                context_lines.append(line)

if __name__ == "__main__":
    input_srt_path = "E:\\Temp\\年末总结\\Timeline 1.srt"  # 输入文件路径
    output_srt_path = "E:\\Temp\\年末总结\\test1.srt"  # 输出文件路径
    main(input_srt_path, output_srt_path)
